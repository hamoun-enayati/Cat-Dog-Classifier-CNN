# %%
import tensorflow as tf
import os
import matplotlib.pyplot as plt
import cv2
import numpy as np

# %%
new_model = tf.keras.models.load_model('cat_dog_classifier.keras')

# %%
test_picture = plt.imread('data/test/cat/cats_00001.jpg')
plt.imshow(test_picture)
plt.show()

# %%
test_picture = cv2.resize(test_picture, (150,150))
test_picture = np.expand_dims(test_picture, axis=0)

# %%
new_model.predict(test_picture)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 162ms/step
# array([[1., 0.]], dtype=float32)
